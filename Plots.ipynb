# %%
# matplotlib Setup
from matplotlib import pyplot as plt 
import numpy as np
plt.rcdefaults() 

# Imports
import csv 
import pandas as pd
import matplotlib.dates as mdates

# %%
# Read in Traffic Experiment Data
jobs2 = pd.read_csv("Traffic Experiment/jobs_2.csv").assign(Traffic = 2)
jobs3 = pd.read_csv("Traffic Experiment/jobs_3.csv").assign(Traffic = 3)
jobs4 = pd.read_csv("Traffic Experiment/jobs_4.csv").assign(Traffic = 4)
jobs5 = pd.read_csv("Traffic Experiment/jobs_5.csv").assign(Traffic = 5)
jobs6 = pd.read_csv("Traffic Experiment/jobs_6.csv").assign(Traffic = 6)

server2 = pd.read_csv("Traffic Experiment/server_2.csv").assign(Traffic = 2)
server3 = pd.read_csv("Traffic Experiment/server_3.csv").assign(Traffic = 3)
server4 = pd.read_csv("Traffic Experiment/server_4.csv").assign(Traffic = 4)
server5 = pd.read_csv("Traffic Experiment/server_5.csv").assign(Traffic = 5)
server6 = pd.read_csv("Traffic Experiment/server_6.csv").assign(Traffic = 6)

traffic_jobs = pd.concat([jobs2,jobs3,jobs4,jobs5,jobs6],ignore_index = True)
traffic_servers = pd.concat([server2,server3,server4,server5,server6],ignore_index = True)

line_size = traffic_servers.iloc[::2,:]
wait_times = traffic_servers.iloc[1::2,:]


#Plots meal rating vs wait time at different traffic levels
fig = plt.figure(figsize=(9,9))
ax1 = fig.add_subplot(3,2,1)
ax1=plt.scatter(jobs2['Wait Time'], jobs2[' Meal Ratings'])
ax2 = fig.add_subplot(3,2,2)
ax2=plt.scatter(jobs3['Wait Time'], jobs3[' Meal Ratings'])
ax3 = fig.add_subplot(3,2,3)
ax3=plt.scatter(jobs4['Wait Time'], jobs4[' Meal Ratings'])
ax4 = fig.add_subplot(3,2,4)
ax4=plt.scatter(jobs5['Wait Time'], jobs5[' Meal Ratings'])
ax5 = fig.add_subplot(3,2,5)
ax5=plt.scatter(jobs6['Wait Time'], jobs6[' Meal Ratings'])
plt.show()

mean_wait = []
mean_meal = []

mean_wait.append([2, jobs2.mean()[0]])
mean_wait.append([3, jobs3.mean()[0]])
mean_wait.append([4, jobs4.mean()[0]])
mean_wait.append([5, jobs5.mean()[0]])
mean_wait.append([6, jobs6.mean()[0]])
mean_wait = np.array(mean_wait)

mean_meal.append([2, jobs2.mean()[1]])
mean_meal.append([3, jobs3.mean()[1]])
mean_meal.append([4, jobs4.mean()[1]])
mean_meal.append([5, jobs5.mean()[1]])
mean_meal.append([6, jobs6.mean()[1]])
mean_meal = np.array(mean_meal)

plt.plot(mean_wait[:,0], mean_wait[:,1])
plt.title("Mean Job Wait Times vs. Traffic (Random Preferences)")
plt.xlabel("Traffic Level")
plt.ylabel("Mean Job Wait Time")
plt.savefig("Mean Job Wait Times vs Traffic (Random Preferences)")
plt.show()

plt.plot(mean_meal[:,0], mean_meal[:,1])
plt.title("Mean Meal Enjoyment vs. Traffic (Random Preferences)")
plt.xlabel("Traffic Level")
plt.ylabel("Mean Meal Enjoyment")
plt.show()

#plots line size vs traffic at all 9 stations
plt.plot(line_size['Traffic'], line_size['Station 1'], label="Card Swipe #1")
plt.plot(line_size['Traffic'], line_size['Station 2'], label="Card Swipe #2")
plt.plot(line_size['Traffic'], line_size['Station 3'], label="Entree 1")
plt.plot(line_size['Traffic'], line_size['Station 4'], label="Entree 2")
plt.plot(line_size['Traffic'], line_size['Station 5'], label="Lighter Side")
plt.plot(line_size['Traffic'], line_size['Station 6'], label="Salad")
plt.plot(line_size['Traffic'], line_size['Station 7'], label="Sandwiches")
plt.plot(line_size['Traffic'], line_size['Station 8'], label="Pasta")
plt.plot(line_size['Traffic'], line_size['Station 9 '], label="Pizza")
plt.title("Line Sizes vs. Traffic (Random Preferences)")
plt.xlabel("Traffic Level")
plt.ylabel("Line Size")
plt.legend()
plt.savefig("Line Sizes vs Traffic (Random Preferences)")
plt.show()

#plots wait times vs traffic level at all 9 stations
plt.plot(wait_times['Traffic'], wait_times['Station 1'], label="Card Swipe #1")
plt.plot(wait_times['Traffic'], wait_times['Station 2'], label="Card Swipe #2")
plt.plot(wait_times['Traffic'], wait_times['Station 3'], label="Entree 1")
plt.plot(wait_times['Traffic'], wait_times['Station 4'], label="Entree 2")
plt.plot(wait_times['Traffic'], wait_times['Station 5'], label="Lighter Side")
plt.plot(wait_times['Traffic'], wait_times['Station 6'], label="Salad")
plt.plot(wait_times['Traffic'], wait_times['Station 7'], label="Sandwiches")
plt.plot(wait_times['Traffic'], wait_times['Station 8'], label="Pasta")
plt.plot(wait_times['Traffic'], wait_times['Station 9 '], label="Pizza")
plt.title("Wait Times vs. Traffic (Random Preferences)")
plt.xlabel("Traffic Level")
plt.ylabel("Wait Time")
plt.legend()
plt.savefig("Wait Times vs Traffic (Random Preferences)")
plt.show()


jobs3 = jobs3.rolling(window=1000).mean()
plt.plot(jobs3['Wait Time'])
plt.title("Wait Times with No Shock (Random Preferences)")
plt.xlabel("")
plt.ylabel("Wait Time")
plt.savefig("Wait Times with No Shock (Random Preferences)")
plt.show()

# %%
#For groups staying together
# Read in Traffic Experiment Data
jobs2 = pd.read_csv("Traffic Experiment Groups/jobs_3.csv").assign(Traffic = 3)
jobs3 = pd.read_csv("Traffic Experiment Groups/jobs_4.csv").assign(Traffic = 4)
jobs4 = pd.read_csv("Traffic Experiment Groups/jobs_5.csv").assign(Traffic = 5)
jobs5 = pd.read_csv("Traffic Experiment Groups/jobs_6.csv").assign(Traffic = 6)
jobs6 = pd.read_csv("Traffic Experiment Groups/jobs_7.csv").assign(Traffic = 7)

server2 = pd.read_csv("Traffic Experiment Groups/server_3.csv").assign(Traffic = 3)
server3 = pd.read_csv("Traffic Experiment Groups/server_4.csv").assign(Traffic = 4)
server4 = pd.read_csv("Traffic Experiment Groups/server_5.csv").assign(Traffic = 5)
server5 = pd.read_csv("Traffic Experiment Groups/server_6.csv").assign(Traffic = 6)
server6 = pd.read_csv("Traffic Experiment Groups/server_7.csv").assign(Traffic = 7)

jobsg2 = pd.read_csv("Traffic Experiment Groups/jobsg_3.csv").assign(Traffic = 3)
jobsg3 = pd.read_csv("Traffic Experiment Groups/jobsg_4.csv").assign(Traffic = 4)
jobsg4 = pd.read_csv("Traffic Experiment Groups/jobsg_5.csv").assign(Traffic = 5)
jobsg5 = pd.read_csv("Traffic Experiment Groups/jobsg_6.csv").assign(Traffic = 6)
jobsg6 = pd.read_csv("Traffic Experiment Groups/jobsg_7.csv").assign(Traffic = 7)

serverg2 = pd.read_csv("Traffic Experiment Groups/serverg_3.csv").assign(Traffic = 3)
serverg3 = pd.read_csv("Traffic Experiment Groups/serverg_4.csv").assign(Traffic = 4)
serverg4 = pd.read_csv("Traffic Experiment Groups/serverg_5.csv").assign(Traffic = 5)
serverg5 = pd.read_csv("Traffic Experiment Groups/serverg_6.csv").assign(Traffic = 6)
serverg6 = pd.read_csv("Traffic Experiment Groups/serverg_7.csv").assign(Traffic = 7)

traffic_jobs = pd.concat([jobs2,jobs3,jobs4,jobs5,jobs6],ignore_index = True)
traffic_servers = pd.concat([server2,server3,server4,server5,server6],ignore_index = True)

traffic_jobs_g = pd.concat([jobsg2,jobsg3,jobsg4,jobsg5,jobsg6],ignore_index = True)
traffic_servers_g = pd.concat([serverg2,serverg3,serverg4,serverg5,serverg6],ignore_index = True)

line_size = traffic_servers.iloc[::2,:]
wait_times = traffic_servers.iloc[1::2,:]

'''
#Plots meal rating vs wait time at different traffic levels
fig = plt.figure(figsize=(9,9))
ax1 = fig.add_subplot(3,2,1)
ax1=plt.scatter(jobs2['Wait Time'], jobs2[' Meal Ratings'])
ax2 = fig.add_subplot(3,2,2)
ax2=plt.scatter(jobs3['Wait Time'], jobs3[' Meal Ratings'])
ax3 = fig.add_subplot(3,2,3)
ax3=plt.scatter(jobs4['Wait Time'], jobs4[' Meal Ratings'])
ax4 = fig.add_subplot(3,2,4)
ax4=plt.scatter(jobs5['Wait Time'], jobs5[' Meal Ratings'])
ax5 = fig.add_subplot(3,2,5)
ax5=plt.scatter(jobs6['Wait Time'], jobs6[' Meal Ratings'])
plt.show()
'''
mean_wait = []
mean_meal = []

mean_wait.append([1.5, jobs2.mean()[0]])
mean_wait.append([2, jobs3.mean()[0]])
mean_wait.append([2.5, jobs4.mean()[0]])
mean_wait.append([3, jobs5.mean()[0]])
mean_wait.append([3.5, jobs6.mean()[0]])
mean_wait = np.array(mean_wait)

mean_wait_g = []
mean_meal_g = []

mean_wait_g.append([1.5, jobsg2.mean()[0]])
mean_wait_g.append([2, jobsg3.mean()[0]])
mean_wait_g.append([2.5, jobsg4.mean()[0]])
mean_wait_g.append([3, jobsg5.mean()[0]])
mean_wait_g.append([3.5, jobsg6.mean()[0]])
mean_wait_g = np.array(mean_wait_g)

plt.plot(mean_wait[:,0], mean_wait[:,1], label="Groups Split")
plt.plot(mean_wait_g[:,0], mean_wait_g[:,1], label="Groups Stay Together")
plt.title("Mean Job Wait Times vs. Traffic (Random Preferences)")
plt.xlabel("Traffic Level")
plt.ylabel("Mean Job Wait Time")
plt.legend()
plt.savefig("Grouped Mean Job Wait Times vs Traffic (Random Preferences)")
plt.show()

'''
#plots line size vs traffic at all 9 stations
plt.plot(line_size['Traffic'], line_size['Station 1'], label="Card Swipe #1")
plt.plot(line_size['Traffic'], line_size['Station 2'], label="Card Swipe #2")
plt.plot(line_size['Traffic'], line_size['Station 3'], label="Entree 1")
plt.plot(line_size['Traffic'], line_size['Station 4'], label="Entree 2")
plt.plot(line_size['Traffic'], line_size['Station 5'], label="Lighter Side")
plt.plot(line_size['Traffic'], line_size['Station 6'], label="Salad")
plt.plot(line_size['Traffic'], line_size['Station 7'], label="Sandwiches")
plt.plot(line_size['Traffic'], line_size['Station 8'], label="Pasta")
plt.plot(line_size['Traffic'], line_size['Station 9 '], label="Pizza")
plt.title("Grouped: Line Sizes vs. Traffic (Random Preferences)")
plt.xlabel("Traffic Level")
plt.ylabel("Line Size")
plt.legend()
plt.savefig("Grouped Line Sizes vs Traffic (Random Preferences)")
plt.show()

#plots wait times vs traffic level at all 9 stations
plt.plot(wait_times['Traffic'], wait_times['Station 1'], label="Card Swipe #1")
plt.plot(wait_times['Traffic'], wait_times['Station 2'], label="Card Swipe #2")
plt.plot(wait_times['Traffic'], wait_times['Station 3'], label="Entree 1")
plt.plot(wait_times['Traffic'], wait_times['Station 4'], label="Entree 2")
plt.plot(wait_times['Traffic'], wait_times['Station 5'], label="Lighter Side")
plt.plot(wait_times['Traffic'], wait_times['Station 6'], label="Salad")
plt.plot(wait_times['Traffic'], wait_times['Station 7'], label="Sandwiches")
plt.plot(wait_times['Traffic'], wait_times['Station 8'], label="Pasta")
plt.plot(wait_times['Traffic'], wait_times['Station 9 '], label="Pizza")
plt.title("Grouped: Wait Times vs. Traffic (Random Preferences)")
plt.xlabel("Traffic Level")
plt.ylabel("Wait Time")
plt.legend()
plt.savefig("Grouped Wait Times vs Traffic (Random Preferences)")
plt.show()


jobs3 = jobs3.rolling(window=1000).mean()
plt.plot(jobs3['Wait Time'])
plt.title("Grouped: Wait Times with No Shock (Random Preferences)")
plt.xlabel("")
plt.ylabel("Wait Time")
plt.savefig("Grouped Wait Times with No Shock (Random Preferences)")
plt.show()'''
# Out:
# '\n#plots line size vs traffic at all 9 stations\nplt.plot(line_size[\'Traffic\'], line_size[\'Station 1\'], label="Card Swipe #1")\nplt.plot(line_size[\'Traffic\'], line_size[\'Station 2\'], label="Card Swipe #2")\nplt.plot(line_size[\'Traffic\'], line_size[\'Station 3\'], label="Entree 1")\nplt.plot(line_size[\'Traffic\'], line_size[\'Station 4\'], label="Entree 2")\nplt.plot(line_size[\'Traffic\'], line_size[\'Station 5\'], label="Lighter Side")\nplt.plot(line_size[\'Traffic\'], line_size[\'Station 6\'], label="Salad")\nplt.plot(line_size[\'Traffic\'], line_size[\'Station 7\'], label="Sandwiches")\nplt.plot(line_size[\'Traffic\'], line_size[\'Station 8\'], label="Pasta")\nplt.plot(line_size[\'Traffic\'], line_size[\'Station 9 \'], label="Pizza")\nplt.title("Grouped: Line Sizes vs. Traffic (Random Preferences)")\nplt.xlabel("Traffic Level")\nplt.ylabel("Line Size")\nplt.legend()\nplt.savefig("Grouped Line Sizes vs Traffic (Random Preferences)")\nplt.show()\n\n#plots wait times vs t
# ...

# %%
# Read in Meal Rating Experiment Data
jobs1 = pd.read_csv("Meal Rating Experiment/jobs_1.csv").assign(entree_rating = 1)
jobs2 = pd.read_csv("Meal Rating Experiment/jobs_2.csv").assign(entree_rating = 2)
jobs3 = pd.read_csv("Meal Rating Experiment/jobs_3.csv").assign(entree_rating = 3)
jobs4 = pd.read_csv("Meal Rating Experiment/jobs_4.csv").assign(entree_rating = 4)
jobs5 = pd.read_csv("Meal Rating Experiment/jobs_5.csv").assign(entree_rating = 5)
jobs6 = pd.read_csv("Meal Rating Experiment/jobs_6.csv").assign(entree_rating = 6)
jobs7 = pd.read_csv("Meal Rating Experiment/jobs_7.csv").assign(entree_rating = 7)
jobs8 = pd.read_csv("Meal Rating Experiment/jobs_8.csv").assign(entree_rating = 8)

server1 = pd.read_csv("Meal Rating Experiment/server_1.csv").assign(entree_rating = 1)
server2 = pd.read_csv("Meal Rating Experiment/server_2.csv").assign(entree_rating = 2)
server3 = pd.read_csv("Meal Rating Experiment/server_3.csv").assign(entree_rating = 3)
server4 = pd.read_csv("Meal Rating Experiment/server_4.csv").assign(entree_rating = 4)
server5 = pd.read_csv("Meal Rating Experiment/server_5.csv").assign(entree_rating = 5)
server6 = pd.read_csv("Meal Rating Experiment/server_6.csv").assign(entree_rating = 6)
server7 = pd.read_csv("Meal Rating Experiment/server_7.csv").assign(entree_rating = 7)
server8 = pd.read_csv("Meal Rating Experiment/server_8.csv").assign(entree_rating = 8)

meal_jobs = np.asarray(pd.concat([jobs1,jobs2,jobs3,jobs4,jobs5,jobs6,jobs7,jobs8],ignore_index = True))
meal_servers = pd.concat([server1,server2,server3,server4,server5,server6,server7,server8],ignore_index = True)

values = []

for i in range(8):
    values.append(3*sum(meal_jobs[meal_jobs[:,2] == i+1]) / meal_jobs[meal_jobs[:,2] == i+1].size)

values = np.asarray(values) 

# Meal Rating vs. Line Size
plt.plot(values[:,2], values[:,0])
plt.title("Line Size vs. Entree Rating (Traffic = 3)")
plt.xlabel("Entree Rating")
plt.ylabel("Line Size")
plt.show()

line_size = meal_servers.iloc[::2,:]
wait_times = meal_servers.iloc[1::2,:]


plt.plot(line_size['entree_rating'], line_size['Station 1'], label="Card Swipe #1")
plt.plot(line_size['entree_rating'], line_size['Station 2'], label="Card Swipe #2")
plt.plot(line_size['entree_rating'], line_size['Station 3'], label="Entree 1")
plt.plot(line_size['entree_rating'], line_size['Station 4'], label="Entree 2")
plt.plot(line_size['entree_rating'], line_size['Station 5'], label="Lighter Side")
plt.plot(line_size['entree_rating'], line_size['Station 6'], label="Salad")
plt.plot(line_size['entree_rating'], line_size['Station 7'], label="Sandwiches")
plt.plot(line_size['entree_rating'], line_size['Station 8'], label="Pasta")
plt.plot(line_size['entree_rating'], line_size['Station 9 '], label="Pizza")
plt.title("Line Sizes vs. Entree Rating (Traffic = 3)")
plt.xlabel("Entree Rating")
plt.ylabel("Line Size")
plt.legend()
plt.savefig("Line Sizes vs Entree Rating (Traffic = 3)")
plt.show()


plt.plot(wait_times['entree_rating'], wait_times['Station 1'], label="Card Swipe #1")
plt.plot(wait_times['entree_rating'], wait_times['Station 2'], label="Card Swipe #2")
plt.plot(wait_times['entree_rating'], wait_times['Station 3'], label="Entree 1")
plt.plot(wait_times['entree_rating'], wait_times['Station 4'], label="Entree 2")
plt.plot(wait_times['entree_rating'], wait_times['Station 5'], label="Lighter Side")
plt.plot(wait_times['entree_rating'], wait_times['Station 6'], label="Salad")
plt.plot(wait_times['entree_rating'], wait_times['Station 7'], label="Sandwiches")
plt.plot(wait_times['entree_rating'], wait_times['Station 8'], label="Pasta")
plt.plot(wait_times['entree_rating'], wait_times['Station 9 '], label="Pizza")
plt.title("Wait Times vs. Entree Rating (Traffic = 3)")
plt.xlabel("Entree Rating")
plt.ylabel("Wait Time")
plt.legend( )
plt.savefig("Wait Times vs Entree Rating (Traffic = 3)")
plt.show()



plt.plot(values[:,2], values[:,1])
plt.title("Satisfaction vs. Entree Rating (Traffic = 3)")
plt.xlabel("Entree Rating")
plt.ylabel("Satisfaction")
plt.savefig("Satisfaction vs Entree Rating (Traffic = 3)")
plt.show()

# %%
#Keeping groups together
# Read in Meal Rating Experiment Data
jobs1 = pd.read_csv("Meal Rating Experiment Groups/jobs_1.csv").assign(entree_rating = 1)
jobs2 = pd.read_csv("Meal Rating Experiment Groups/jobs_2.csv").assign(entree_rating = 2)
jobs3 = pd.read_csv("Meal Rating Experiment Groups/jobs_3.csv").assign(entree_rating = 3)
jobs4 = pd.read_csv("Meal Rating Experiment Groups/jobs_4.csv").assign(entree_rating = 4)
jobs5 = pd.read_csv("Meal Rating Experiment Groups/jobs_5.csv").assign(entree_rating = 5)
jobs6 = pd.read_csv("Meal Rating Experiment Groups/jobs_6.csv").assign(entree_rating = 6)
jobs7 = pd.read_csv("Meal Rating Experiment Groups/jobs_7.csv").assign(entree_rating = 7)
jobs8 = pd.read_csv("Meal Rating Experiment Groups/jobs_8.csv").assign(entree_rating = 8)

server1 = pd.read_csv("Meal Rating Experiment Groups/server_1.csv").assign(entree_rating = 1)
server2 = pd.read_csv("Meal Rating Experiment Groups/server_2.csv").assign(entree_rating = 2)
server3 = pd.read_csv("Meal Rating Experiment Groups/server_3.csv").assign(entree_rating = 3)
server4 = pd.read_csv("Meal Rating Experiment Groups/server_4.csv").assign(entree_rating = 4)
server5 = pd.read_csv("Meal Rating Experiment Groups/server_5.csv").assign(entree_rating = 5)
server6 = pd.read_csv("Meal Rating Experiment Groups/server_6.csv").assign(entree_rating = 6)
server7 = pd.read_csv("Meal Rating Experiment Groups/server_7.csv").assign(entree_rating = 7)
server8 = pd.read_csv("Meal Rating Experiment Groups/server_8.csv").assign(entree_rating = 8)

meal_jobs = np.asarray(pd.concat([jobs1,jobs2,jobs3,jobs4,jobs5,jobs6,jobs7,jobs8],ignore_index = True))
meal_servers = pd.concat([server1,server2,server3,server4,server5,server6,server7,server8],ignore_index = True)

values = []

for i in range(8):
    values.append(3*sum(meal_jobs[meal_jobs[:,2] == i+1]) / meal_jobs[meal_jobs[:,2] == i+1].size)

values = np.asarray(values) 

# Meal Rating vs. Line Size
plt.plot(values[:,2], values[:,0])
plt.title("Grouped: Line Size vs. Entree Rating (Traffic = 3)")
plt.xlabel("Entree Rating")
plt.ylabel("Line Size")
#plt.savefig("Grouped: Line Size vs Entree Rating (Traffic = 3)")
plt.show()

line_size = meal_servers.iloc[::2,:]
wait_times = meal_servers.iloc[1::2,:]


plt.plot(line_size['entree_rating'], line_size['Station 1'], label="Card Swipe #1")
plt.plot(line_size['entree_rating'], line_size['Station 2'], label="Card Swipe #2")
plt.plot(line_size['entree_rating'], line_size['Station 3'], label="Entree 1")
plt.plot(line_size['entree_rating'], line_size['Station 4'], label="Entree 2")
plt.plot(line_size['entree_rating'], line_size['Station 5'], label="Lighter Side")
plt.plot(line_size['entree_rating'], line_size['Station 6'], label="Salad")
plt.plot(line_size['entree_rating'], line_size['Station 7'], label="Sandwiches")
plt.plot(line_size['entree_rating'], line_size['Station 8'], label="Pasta")
plt.plot(line_size['entree_rating'], line_size['Station 9 '], label="Pizza")
plt.title("Grouped: Line Sizes vs. Entree Rating (Traffic = 3)")
plt.xlabel("Entree Rating")
plt.ylabel("Line Size")
plt.legend()
plt.savefig("Grouped Line Sizes vs Entree Rating (Traffic = 3)")
plt.show()


plt.plot(wait_times['entree_rating'], wait_times['Station 1'], label="Card Swipe #1")
plt.plot(wait_times['entree_rating'], wait_times['Station 2'], label="Card Swipe #2")
plt.plot(wait_times['entree_rating'], wait_times['Station 3'], label="Entree 1")
plt.plot(wait_times['entree_rating'], wait_times['Station 4'], label="Entree 2")
plt.plot(wait_times['entree_rating'], wait_times['Station 5'], label="Lighter Side")
plt.plot(wait_times['entree_rating'], wait_times['Station 6'], label="Salad")
plt.plot(wait_times['entree_rating'], wait_times['Station 7'], label="Sandwiches")
plt.plot(wait_times['entree_rating'], wait_times['Station 8'], label="Pasta")
plt.plot(wait_times['entree_rating'], wait_times['Station 9 '], label="Pizza")
plt.title("Grouped: Wait Times vs. Entree Rating (Traffic = 3)")
plt.xlabel("Entree Rating")
plt.ylabel("Wait Time")
plt.legend( )
plt.savefig("Grouped Wait Times vs Entree Rating (Traffic = 3)")
plt.show()



plt.plot(values[:,2], values[:,1])
plt.title("Grouped: Satisfaction vs. Entree Rating (Traffic = 3)")
plt.xlabel("Entree Rating")
plt.ylabel("Satisfaction")
plt.savefig("Grouped Satisfaction vs Entree Rating (Traffic = 3)")
plt.show()

# %%
# Read in Shock Experiment Data
jobsb = pd.read_csv("Shock Experiment/jobs_shock_b.csv").assign(Entree = "Bad")
jobsr = pd.read_csv("Shock Experiment/jobs_shock_r.csv").assign(Entree = "Random")
jobsg = pd.read_csv("Shock Experiment/jobs_shock_g.csv").assign(Entree = "Great")

serverb = pd.read_csv("Shock Experiment/server_shock_b.csv").assign(Entree = "Bad")
serverr = pd.read_csv("Shock Experiment/server_shock_r.csv").assign(Entree = "Random")
serverg = pd.read_csv("Shock Experiment/server_shock_g.csv").assign(Entree = "Great")

shock_jobs = pd.concat([jobsb,jobsg,jobsr],ignore_index = True)
shock_servers = pd.concat([serverb,serverg,serverr],ignore_index = True)


jobsr = jobsr.rolling(window=1000).mean()
jobsb = jobsb.rolling(window=1000).mean()
jobsg = jobsg.rolling(window=1000).mean()

# %%
plt.plot(jobsr[' Meal Ratings'])
plt.title("Satisfaction During Shock (Random Preferences)")
plt.xlabel("")
plt.ylabel("Satisfaction")
plt.savefig("Satisfaction During Shock (Random Preferences)")
plt.show()

plt.plot(jobsb[' Meal Ratings'])
plt.title("Satisfaction During Shock (Bad Val Meal)")
plt.xlabel("")
plt.ylabel("Satisfaction")
plt.savefig("Satisfaction During Shock (Bad Val Meal)")
plt.show()

plt.plot(jobsg[' Meal Ratings'])
plt.title("Satisfaction During Shock (Great Val Meal)")
plt.xlabel("")
plt.ylabel("Satisfaction")
plt.savefig("Satisfaction During Shock (Great Val Meal)")
plt.show()





plt.plot(jobsr['Wait Time'])
plt.title("Wait Times During Shock (Random Preferences)")
plt.xlabel("")
plt.ylabel("Wait Time")
plt.savefig("Wait Time During Shock (Random Preferences)")
plt.show()

plt.plot(jobsb['Wait Time'])
plt.title("Wait Times During Shock (Bad Val Meal)")
plt.xlabel("")
plt.ylabel("Wait Time")
plt.savefig("Wait Time During Shock (Bad Val Meal)")
plt.show()

plt.plot(jobsg['Wait Time'])
plt.title("Wait Times During Shock (Great Val Meal)")
plt.xlabel("")
plt.ylabel("Wait Time")
plt.savefig("Wait Time During Shock (Great Val Meal)")
plt.show()

# %%
# Read in Shock Experiment Data

jobsr = pd.read_csv("Shock Experiment Groups/jobs_shock_r.csv").assign(Entree = "Random")
serverr = pd.read_csv("Shock Experiment Groups/server_shock_r.csv").assign(Entree = "Random")
jobsr = jobsr.rolling(window=1000).mean()

plt.plot(jobsr[' Meal Ratings'])
plt.title("Grouped: Satisfaction During Shock (Random Preferences)")
plt.xlabel("")
plt.ylabel("Satisfaction")
plt.savefig("Grouped Satisfaction During Shock (Random Preferences)")
plt.show()

plt.plot(jobsr['Wait Time'])
plt.title("Grouped: Wait Times During Shock (Random Preferences)")
plt.xlabel("")
plt.ylabel("Wait Time")
plt.savefig("Grouped Wait Time During Shock (Random Preferences)")
plt.show()

# %%
# Read in Meal Rating Experiment Data
jobs1 = pd.read_csv("Side Rating Experiment/jobs_1.csv").assign(entree_rating = 1)
jobs2 = pd.read_csv("Side Rating Experiment/jobs_2.csv").assign(entree_rating = 2)
jobs3 = pd.read_csv("Side Rating Experiment/jobs_3.csv").assign(entree_rating = 3)
jobs4 = pd.read_csv("Side Rating Experiment/jobs_4.csv").assign(entree_rating = 4)
jobs5 = pd.read_csv("Side Rating Experiment/jobs_5.csv").assign(entree_rating = 5)
jobs6 = pd.read_csv("Side Rating Experiment/jobs_6.csv").assign(entree_rating = 6)
jobs7 = pd.read_csv("Side Rating Experiment/jobs_7.csv").assign(entree_rating = 7)
#jobs8 = pd.read_csv("Side Rating Experiment/jobs_8.csv").assign(entree_rating = 8)

server1 = pd.read_csv("Side Rating Experiment/server_1.csv").assign(entree_rating = 1)
server2 = pd.read_csv("Side Rating Experiment/server_2.csv").assign(entree_rating = 2)
server3 = pd.read_csv("Side Rating Experiment/server_3.csv").assign(entree_rating = 3)
server4 = pd.read_csv("Side Rating Experiment/server_4.csv").assign(entree_rating = 4)
server5 = pd.read_csv("Side Rating Experiment/server_5.csv").assign(entree_rating = 5)
server6 = pd.read_csv("Side Rating Experiment/server_6.csv").assign(entree_rating = 6)
server7 = pd.read_csv("Side Rating Experiment/server_7.csv").assign(entree_rating = 7)
#server8 = pd.read_csv("Side Rating Experiment/server_8.csv").assign(entree_rating = 8)

meal_jobs = np.asarray(pd.concat([jobs1,jobs2,jobs3,jobs4,jobs5,jobs6,jobs7],ignore_index = True))
meal_servers = pd.concat([server1,server2,server3,server4,server5,server6,server7],ignore_index = True)

values = []

for i in range(7):
    values.append(3*sum(meal_jobs[meal_jobs[:,2] == i+1]) / meal_jobs[meal_jobs[:,2] == i+1].size)

values = np.asarray(values) 

# Meal Rating vs. Line Size
plt.plot(values[:,2], values[:,0])
plt.title("Wait Times vs. Side Rating (Traffic = 3)")
plt.xlabel("Side Rating")
plt.ylabel("Wait Times")
plt.show()

line_size = meal_servers.iloc[::2,:]
wait_times = meal_servers.iloc[1::2,:]


plt.plot(line_size['entree_rating'], line_size['Station 1'], label="Card Swipe #1")
plt.plot(line_size['entree_rating'], line_size['Station 2'], label="Card Swipe #2")
plt.plot(line_size['entree_rating'], line_size['Station 3'], label="Entree 1")
plt.plot(line_size['entree_rating'], line_size['Station 4'], label="Entree 2")
plt.plot(line_size['entree_rating'], line_size['Station 5'], label="Lighter Side")
plt.plot(line_size['entree_rating'], line_size['Station 6'], label="Salad")
plt.plot(line_size['entree_rating'], line_size['Station 7'], label="Sandwiches")
plt.plot(line_size['entree_rating'], line_size['Station 8'], label="Pasta")
plt.plot(line_size['entree_rating'], line_size['Station 9 '], label="Pizza")
plt.title("Line Sizes vs. Side Rating (Traffic = 3)")
plt.xlabel("Side Rating")
plt.ylabel("Line Size")
plt.legend()
plt.savefig("Line Sizes vs Side Rating (Traffic = 3)")
plt.show()


plt.plot(wait_times['entree_rating'], wait_times['Station 1'], label="Card Swipe #1")
plt.plot(wait_times['entree_rating'], wait_times['Station 2'], label="Card Swipe #2")
plt.plot(wait_times['entree_rating'], wait_times['Station 3'], label="Entree 1")
plt.plot(wait_times['entree_rating'], wait_times['Station 4'], label="Entree 2")
plt.plot(wait_times['entree_rating'], wait_times['Station 5'], label="Lighter Side")
plt.plot(wait_times['entree_rating'], wait_times['Station 6'], label="Salad")
plt.plot(wait_times['entree_rating'], wait_times['Station 7'], label="Sandwiches")
plt.plot(wait_times['entree_rating'], wait_times['Station 8'], label="Pasta")
plt.plot(wait_times['entree_rating'], wait_times['Station 9 '], label="Pizza")
plt.title("Wait Times vs. Side Rating (Traffic = 3)")
plt.xlabel("Side Rating")
plt.ylabel("Wait Time")
plt.legend( )
plt.savefig("Wait Times vs Side Rating (Traffic = 3)")
plt.show()



plt.plot(values[:,2], values[:,1])
plt.title("Satisfaction vs. Side Rating (Traffic = 3)")
plt.xlabel("Entree Rating")
plt.ylabel("Satisfaction")
plt.savefig("Satisfaction vs Side Rating (Traffic = 3)")
plt.show()

# %%
# Read in Meal Rating Experiment Data
jobs1 = pd.read_csv("Portion Size Experiment/jobs_1.csv").assign(portion = 0.4)
jobs2 = pd.read_csv("Portion Size Experiment/jobs_2.csv").assign(portion = 0.41)
jobs3 = pd.read_csv("Portion Size Experiment/jobs_3.csv").assign(portion = 0.42)
jobs4 = pd.read_csv("Portion Size Experiment/jobs_4.csv").assign(portion = 0.43)
jobs5 = pd.read_csv("Portion Size Experiment/jobs_5.csv").assign(portion = 0.44)
jobs6 = pd.read_csv("Portion Size Experiment/jobs_6.csv").assign(portion = 0.45)
jobs7 = pd.read_csv("Portion Size Experiment/jobs_7.csv").assign(portion = 0.46)
jobs8 = pd.read_csv("Portion Size Experiment/jobs_8.csv").assign(portion = 0.47)
jobs9 = pd.read_csv("Portion Size Experiment/jobs_9.csv").assign(portion = 0.48)
jobs10 = pd.read_csv("Portion Size Experiment/jobs_10.csv").assign(portion = 0.49)
jobs11 = pd.read_csv("Portion Size Experiment/jobs_11.csv").assign(portion = 0.5)
jobs12 = pd.read_csv("Portion Size Experiment/jobs_12.csv").assign(portion = 0.51)
jobs13 = pd.read_csv("Portion Size Experiment/jobs_13.csv").assign(portion = 0.52)
jobs14 = pd.read_csv("Portion Size Experiment/jobs_14.csv").assign(portion = 0.53)
jobs15 = pd.read_csv("Portion Size Experiment/jobs_15.csv").assign(portion = 0.54)
jobs16 = pd.read_csv("Portion Size Experiment/jobs_16.csv").assign(portion = 0.55)
jobs17 = pd.read_csv("Portion Size Experiment/jobs_17.csv").assign(portion = 0.56)
jobs18 = pd.read_csv("Portion Size Experiment/jobs_18.csv").assign(portion = 0.57)
jobs19 = pd.read_csv("Portion Size Experiment/jobs_19.csv").assign(portion = 0.58)
jobs20 = pd.read_csv("Portion Size Experiment/jobs_20.csv").assign(portion = 0.59)

meal_jobs = np.asarray(pd.concat([jobs1,jobs2,jobs3,jobs4,jobs5,jobs6,jobs7,jobs8,jobs9,jobs10,jobs11,jobs12,jobs13,jobs14,jobs15,jobs16,jobs17,jobs18,jobs19,jobs20],ignore_index = True))

values = []

for i in [0.4, 0.41, 0.42, 0.43, 0.44, 0.45, 0.46, 0.47, 0.48, 0.49, 0.5,0.51, 0.52, 0.53, 0.54, 0.55, 0.56, 0.57, 0.58, 0.59]:
    values.append(3*sum(meal_jobs[meal_jobs[:,2] == i]) / (meal_jobs[meal_jobs[:,2] == i].size))

values = np.asarray(values)

# Meal Rating vs. Wait Time
plt.plot(values[:,2], values[:,0])
plt.title("Wait Time vs. Portion Constant (Baseline Conditions)")
plt.xlabel("Portion Constant")
plt.ylabel("Wait Time")
plt.savefig("Wait Time vs Portion Constant (Baseline Conditions)")
plt.show()
